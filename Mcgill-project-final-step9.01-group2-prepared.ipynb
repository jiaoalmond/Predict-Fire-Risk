# %%
import pandas as pd
import numpy as np 

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
path = "D:/MCGILL-DATA SCIENCE/YCBS-299-PRJ/data/jjycleaned/2015-2019/"

# %%
group1 = path + "group1.csv"
group1= pd.read_csv(group1)
group1.sort_values(['DATE']).head()
# Out:
#              DATE  YEAR QUART INCIDENT_TYPE_DESC DESCRIPTION_GROUPE  \
# 6626   2015-01-01  2015  jour     10-22 avec feu           INCENDIE
# 10682  2015-01-01  2015  soir     10-22 avec feu           INCENDIE
# 6509   2015-01-01  2015  nuit     10-22 avec feu           INCENDIE
# 6628   2015-01-01  2015  jour     10-22 avec feu           INCENDIE
# 6627   2015-01-01  2015  jour     10-22 avec feu           INCENDIE
#
#                       ARRONDISSEMENT  FIRE_RISK_RATE_YR RISK_LVL  \
# 6626   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
# 10682                      WESTMOUNT           0.008496      Low
# 6509   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
# 6628   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
# 6627   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
#
#           CATEGORIE  Temp_avg  Dew_avg  Hum_avg  Wind_avg  Revenu moyen ($)  \
# 6626         Méfait     -3.82    -7.74    74.75     27.75             36709
# ...

# %%
group2 = group1[['DATE','YEAR','QUART','ARRONDISSEMENT','RISK_LVL', 'CATEGORIE','Revenu moyen ($)','Population_Density','NOMBRE_LOGEMENT','Average_Age','Avg_members_family']]

# %%
group2['ARRONDISSEMENT'].value_counts()
# Out:
# VILLE-MARIE                                 2132
# MERCIER-HOCHELAGA-MAISONNEUVE               1149
# ROSEMONT-LA PETITE-PATRIE                   1018
# AHUNTSIC-CARTIERVILLE                        798
# COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE          637
# VILLERAY-SAINT-MICHEL-PARC-EXTENSION         605
# LE SUD-OUEST                                 589
# LE PLATEAU-MONT-ROYAL                        525
# MONTREAL-NORD                                454
# SAINT-LAURENT                                441
# RIVIERE-DES-PRAIRIES-POINTE-AUX-TREMBLES     301
# SAINT-LEONARD                                267
# VERDUN                                       215
# LASALLE                                      212
# PIERREFONDS-ROXBORO                          184
# LACHINE                                      158
# DORVAL                                       133
# ANJOU                                        127
# MONT-ROYAL                                   114
# ...

# %%
immig_edu = path + "population_data_prepped_with_extra.xlsx"
immig_edu = pd.read_excel(immig_edu)
immig_edu.head()
# Out:
#                               Areas_OG                             Areas_JY  \
# 0                Ahuntsic-Cartierville                AHUNTSIC-CARTIERVILLE
# 1                                Anjou                                ANJOU
# 2                          Baie-D'Urfé                          BAIE-D'URFE
# 3                         Beaconsfield                         BEACONSFIELD
# 4  Côte-des-Neiges–Notre-Dame-de-Grâce  COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE
#
#                               Areas_PR  Population_Density  Average_Age  \
# 0                AHUNTSIC-CARTIERVILLE         5556.498344         41.6
# 1                                ANJOU         3128.362573         43.9
# 2                          BAIE-D'URFE          635.789124         45.3
# 3                         BEACONSFIELD         1759.927140         41.7
# 4  COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE         7766.791045         38.7
#
#    Median_Age  Pop_Single_Percentage  Avg_members_family  \
# ...

# %%
immig_edu = immig_edu[['Areas_PR','renters_%','Population Immigrants','Aucun certificat, diplôme ou grade']]

# %%
immig_edu=immig_edu.rename(columns = {'Areas_PR':'ARRONDISSEMENT'})

# %%
immig_edu
# Out:
#                               ARRONDISSEMENT  renters_%  \
# 0                      AHUNTSIC-CARTIERVILLE   0.607782
# 1                                      ANJOU   0.556915
# 2                                BAIE-D'URFE   0.059925
# 3                               BEACONSFIELD   0.102776
# 4        COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE   0.733218
# 5                             COTE-SAINT-LUC   0.508895
# 6                        DOLLARD-DES-ORMEAUX   0.234747
# 7                                     DORVAL   0.401073
# 8                                  HAMPSTEAD   0.331313
# 9                                   KIRKLAND   0.054600
# 10             L'ILE-BIZARD-SAINTE-GENEVIEVE   0.259740
# 11                                   LACHINE   0.573042
# 12                                   LASALLE   0.600842
# 13                     LE PLATEAU-MONT-ROYAL   0.724123
# 14                              LE SUD-OUEST   0.657678
# 15             MERCIER-HOCHELAGA-MAISONNEUVE   0.655844
# ...

# %%
group2 = pd.merge(group2, immig_edu, how='inner', on=['ARRONDISSEMENT'])

# %%
group2.head()
# Out:
#          DATE  YEAR QUART ARRONDISSEMENT RISK_LVL                 CATEGORIE  \
# 0  2019-01-07  2019  jour  POINTE-CLAIRE      Low                       NaN
# 1  2019-01-11  2019  jour  POINTE-CLAIRE      Low              Introduction
# 2  2019-09-27  2019  soir  POINTE-CLAIRE      Low              Introduction
# 3  2019-09-27  2019  soir  POINTE-CLAIRE      Low  Vol de véhicule à moteur
# 4  2019-01-18  2019  soir  POINTE-CLAIRE      Low                    Méfait
#
#    Revenu moyen ($)  Population_Density  NOMBRE_LOGEMENT  Average_Age  \
# 0             51488         1665.605096         1.403955         45.3
# 1             51488         1665.605096         1.403955         45.3
# 2             51488         1665.605096         1.403955         45.3
# 3             51488         1665.605096         1.403955         45.3
# 4             51488         1665.605096         1.403955         45.3
#
#    Avg_members_family  renters_%  Population Immigrants  \
# ...

# %%
group2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10782 entries, 0 to 10781
# Data columns (total 14 columns):
# DATE                                  10782 non-null object
# YEAR                                  10782 non-null int64
# QUART                                 10782 non-null object
# ARRONDISSEMENT                        10782 non-null object
# RISK_LVL                              10782 non-null object
# CATEGORIE                             8448 non-null object
# Revenu moyen ($)                      10782 non-null int64
# Population_Density                    10782 non-null float64
# NOMBRE_LOGEMENT                       10782 non-null float64
# Average_Age                           10782 non-null float64
# Avg_members_family                    10782 non-null float64
# renters_%                             10782 non-null float64
# Population Immigrants                 10782 non-null float64
# Aucun certificat, diplôme ou grade    10782 non-null float64
# ...

# %%
group2.isnull().sum()
# Out:
# DATE                                     0
# YEAR                                     0
# QUART                                    0
# ARRONDISSEMENT                           0
# RISK_LVL                                 0
# CATEGORIE                             2334
# Revenu moyen ($)                         0
# Population_Density                       0
# NOMBRE_LOGEMENT                          0
# Average_Age                              0
# Avg_members_family                       0
# renters_%                                0
# Population Immigrants                    0
# Aucun certificat, diplôme ou grade       0
# dtype: int64

# %%
# save group2
group2.to_csv("D:/MCGILL-DATA SCIENCE/YCBS-299-PRJ/data/jjycleaned/2015-2019/group2.csv", index=False)
