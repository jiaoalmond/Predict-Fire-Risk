# %%
import pandas as pd
import numpy as np 

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
path = "D:/MCGILL-DATA SCIENCE/YCBS-299-PRJ/data/jjycleaned/2015-2019/"
pop = path + "population_data_prepped.csv"
pop= pd.read_csv(pop)
pop.head()
# Out:
#                               Areas_OG                             Areas_JY  \
# 0                Ahuntsic-Cartierville                AHUNTSIC-CARTIERVILLE
# 1                                Anjou                                ANJOU
# 2                          Baie-D'Urfé                          BAIE-D'URFE
# 3                         Beaconsfield                         BEACONSFIELD
# 4  Côte-des-Neiges–Notre-Dame-de-Grâce  COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE
#
#                               Areas_PR  Population_Density  Average_Age  \
# 0                AHUNTSIC-CARTIERVILLE         5556.498344         41.6
# 1                                ANJOU         3128.362573         43.9
# 2                          BAIE-D'URFE          635.789124         45.3
# 3                         BEACONSFIELD         1759.927140         41.7
# 4  COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE         7766.791045         38.7
#
#    Median_Age  Pop_Single_Percentage  Avg_members_family  \
# ...

# %%
build = path + "building_data_calc.csv"
build= pd.read_csv(build)
build.head()
# Out:
#                         ARRONDISSEMENT  ANNEE_CONSTRUCTION  ETAGE_HORS_SOL  \
# 0                            WESTMOUNT         1932.040472        2.029333
# 1                       MONTREAL-OUEST         1941.091491        1.899160
# 2                            OUTREMONT         1944.838358        1.828079
# 3                LE PLATEAU-MONT-ROYAL         1945.016827        1.983523
# 4  COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE         1957.831310        1.899546
#
#    NOMBRE_LOGEMENT  avg_building_age floor_level unit_level blg_age_level
# 0         1.939744         87.959528        High     Medium          High
# 1         1.314924         78.908509        High        Low          High
# 2         1.835369         75.161642      Medium     Medium          High
# 3         2.877578         74.983173        High       High          High
# 4         3.429431         62.168690        High       High          High

# %%
pop.info()
build.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
# Areas_OG                           32 non-null object
# Areas_JY                           32 non-null object
# Areas_PR                           32 non-null object
# Population_Density                 32 non-null float64
# Average_Age                        32 non-null float64
# Median_Age                         32 non-null float64
# Pop_Single_Percentage              32 non-null float64
# Avg_members_family                 32 non-null float64
# Families_3more_child_percentage    32 non-null float64
# renters_%                          32 non-null float64
# Réparations majeures requises_%    32 non-null float64
# Revenu médian ($)                  32 non-null int64
# Revenu moyen ($)                   32 non-null int64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 3.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# ...

# %% [markdown]
# ## Merge the two datasets

# %%
pop = pop.rename(columns = {'Areas_PR':'ARRONDISSEMENT'})
pop = pop.drop(columns=['Areas_OG','Areas_JY'])
pop
# Out:
#                               ARRONDISSEMENT  Population_Density  Average_Age  \
# 0                      AHUNTSIC-CARTIERVILLE         5556.498344         41.6
# 1                                      ANJOU         3128.362573         43.9
# 2                                BAIE-D'URFE          635.789124         45.3
# 3                               BEACONSFIELD         1759.927140         41.7
# 4        COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE         7766.791045         38.7
# 5                             COTE-SAINT-LUC         4675.504323         45.8
# 6                        DOLLARD-DES-ORMEAUX         3223.401450         41.9
# 7                                     DORVAL          910.311751         43.5
# 8                                  HAMPSTEAD         3904.255319         40.1
# 9                                   KIRKLAND         2093.827930         41.9
# 10             L'ILE-BIZARD-SAINTE-GENEVIEVE          780.211864         42.1
# ...

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
# ARRONDISSEMENT                     32 non-null object
# Population_Density                 32 non-null float64
# Average_Age                        32 non-null float64
# Median_Age                         32 non-null float64
# Pop_Single_Percentage              32 non-null float64
# Avg_members_family                 32 non-null float64
# Families_3more_child_percentage    32 non-null float64
# renters_%                          32 non-null float64
# Réparations majeures requises_%    32 non-null float64
# Revenu médian ($)                  32 non-null int64
# Revenu moyen ($)                   32 non-null int64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 2.9+ KB

# %%
build_pop = pd.merge (build, pop, how='inner', on=['ARRONDISSEMENT'])
build_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 18 columns):
# ARRONDISSEMENT                     32 non-null object
# ANNEE_CONSTRUCTION                 32 non-null float64
# ETAGE_HORS_SOL                     32 non-null float64
# NOMBRE_LOGEMENT                    32 non-null float64
# avg_building_age                   32 non-null float64
# floor_level                        32 non-null object
# unit_level                         32 non-null object
# blg_age_level                      32 non-null object
# Population_Density                 32 non-null float64
# Average_Age                        32 non-null float64
# Median_Age                         32 non-null float64
# Pop_Single_Percentage              32 non-null float64
# Avg_members_family                 32 non-null float64
# Families_3more_child_percentage    32 non-null float64
# renters_%                          32 non-null float64
# ...

# %% [markdown]
# "Revenu moyen ($) ","Population_Density ","NOMBRE_LOGEMENT","blg_age_level","Average_Age","Avg_members_family"

# %%
build_pop.head()
# Out:
#                         ARRONDISSEMENT  ANNEE_CONSTRUCTION  ETAGE_HORS_SOL  \
# 0                            WESTMOUNT         1932.040472        2.029333
# 1                       MONTREAL-OUEST         1941.091491        1.899160
# 2                            OUTREMONT         1944.838358        1.828079
# 3                LE PLATEAU-MONT-ROYAL         1945.016827        1.983523
# 4  COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE         1957.831310        1.899546
#
#    NOMBRE_LOGEMENT  avg_building_age floor_level unit_level blg_age_level  \
# 0         1.939744         87.959528        High     Medium          High
# 1         1.314924         78.908509        High        Low          High
# 2         1.835369         75.161642      Medium     Medium          High
# 3         2.877578         74.983173        High       High          High
# 4         3.429431         62.168690        High       High          High
#
# ...

# %%
build_pop.round(decimals=2)
# Out:
#                               ARRONDISSEMENT  ANNEE_CONSTRUCTION  \
# 0                                  WESTMOUNT             1932.04
# 1                             MONTREAL-OUEST             1941.09
# 2                                  OUTREMONT             1944.84
# 3                      LE PLATEAU-MONT-ROYAL             1945.02
# 4        COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE             1957.83
# 5       VILLERAY-SAINT-MICHEL-PARC-EXTENSION             1958.31
# 6                                  HAMPSTEAD             1958.70
# 7                  ROSEMONT-LA PETITE-PATRIE             1960.77
# 8                    SAINTE-ANNE-DE-BELLEVUE             1963.71
# 9                                 MONT-ROYAL             1964.62
# 10             MERCIER-HOCHELAGA-MAISONNEUVE             1965.35
# 11                             MONTREAL-NORD             1968.10
# 12                             POINTE-CLAIRE             1970.49
# ...

# %%
build_pop1 = build_pop[["ARRONDISSEMENT","Revenu moyen ($)","Population_Density","NOMBRE_LOGEMENT","blg_age_level","Average_Age","Avg_members_family"]]

# %%
build_pop1
#save build_pop1
build_pop1.to_csv('D:/MCGILL-DATA SCIENCE/YCBS-299-PRJ/data/jjycleaned/2015-2019/build_pop1.csv', index = False)
# Out:
#                               ARRONDISSEMENT  Revenu moyen ($)  \
# 0                                  WESTMOUNT            162473
# 1                             MONTREAL-OUEST             75538
# 2                                  OUTREMONT             97237
# 3                      LE PLATEAU-MONT-ROYAL             43128
# 4        COTE-DES-NEIGES-NOTRE-DAME-DE-GRACE             38937
# 5       VILLERAY-SAINT-MICHEL-PARC-EXTENSION             30824
# 6                                  HAMPSTEAD            114120
# 7                  ROSEMONT-LA PETITE-PATRIE             41184
# 8                    SAINTE-ANNE-DE-BELLEVUE             54439
# 9                                 MONT-ROYAL            100943
# 10             MERCIER-HOCHELAGA-MAISONNEUVE             36709
# 11                             MONTREAL-NORD             28820
# 12                             POINTE-CLAIRE             51488
# 13                              BEACONSFIELD             85174
# ...

# %%
incident_crime_weather = path + "incident_crime_weather.csv"
incident_crime_weather= pd.read_csv(incident_crime_weather)
incident_crime_weather.sort_values(['DATE']).head()
# Out:
#              DATE  YEAR QUART INCIDENT_TYPE_DESC DESCRIPTION_GROUPE  \
# 6626   2015-01-01  2015  jour     10-22 avec feu           INCENDIE
# 10682  2015-01-01  2015  soir     10-22 avec feu           INCENDIE
# 6509   2015-01-01  2015  nuit     10-22 avec feu           INCENDIE
# 6628   2015-01-01  2015  jour     10-22 avec feu           INCENDIE
# 6627   2015-01-01  2015  jour     10-22 avec feu           INCENDIE
#
#                       ARRONDISSEMENT  FIRE_RISK_RATE_YR RISK_LVL  \
# 6626   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
# 10682                      WESTMOUNT           0.008496      Low
# 6509   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
# 6628   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
# 6627   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
#
#           CATEGORIE  Temp_avg  Dew_avg  Hum_avg  Wind_avg
# 6626         Méfait     -3.82    -7.74    74.75     27.75
# ...

# %%
group1 = pd.merge (incident_crime_weather, build_pop1, how='left', on=['ARRONDISSEMENT'])
group1.head()
group1.info()
# Out:
#          DATE  YEAR QUART INCIDENT_TYPE_DESC DESCRIPTION_GROUPE  \
# 0  2019-01-07  2019  jour    Feu de bâtiment           INCENDIE
# 1  2019-01-11  2019  jour     10-22 avec feu           INCENDIE
# 2  2019-09-27  2019  soir  Feu de cuisinière           INCENDIE
# 3  2019-09-27  2019  soir  Feu de cuisinière           INCENDIE
# 4  2019-01-18  2019  soir     10-22 avec feu           INCENDIE
#
#   ARRONDISSEMENT  FIRE_RISK_RATE_YR RISK_LVL                 CATEGORIE  \
# 0  POINTE-CLAIRE           0.014108      Low                       NaN
# 1  POINTE-CLAIRE           0.014108      Low              Introduction
# 2  POINTE-CLAIRE           0.014108      Low              Introduction
# 3  POINTE-CLAIRE           0.014108      Low  Vol de véhicule à moteur
# 4  POINTE-CLAIRE           0.014108      Low                    Méfait
#
#    Temp_avg  Dew_avg  Hum_avg  Wind_avg  Revenu moyen ($)  Population_Density  \
# ...

# %%
#save group1
group1.to_csv('D:/MCGILL-DATA SCIENCE/YCBS-299-PRJ/data/jjycleaned/2015-2019/group1.csv', index = False)
