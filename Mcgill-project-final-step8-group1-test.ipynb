# %%
import pandas as pd
import numpy as np 

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
path = "D:/MCGILL-DATA SCIENCE/YCBS-299-PRJ/data/jjycleaned/2015-2019/"

# %%
group1 = path + "group1.csv"
group1= pd.read_csv(group1)
group1.sort_values(['DATE']).head()
# Out:
#              DATE  YEAR QUART INCIDENT_TYPE_DESC DESCRIPTION_GROUPE  \
# 6626   2015-01-01  2015  jour     10-22 avec feu           INCENDIE
# 10682  2015-01-01  2015  soir     10-22 avec feu           INCENDIE
# 6509   2015-01-01  2015  nuit     10-22 avec feu           INCENDIE
# 6628   2015-01-01  2015  jour     10-22 avec feu           INCENDIE
# 6627   2015-01-01  2015  jour     10-22 avec feu           INCENDIE
#
#                       ARRONDISSEMENT  FIRE_RISK_RATE_YR RISK_LVL  \
# 6626   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
# 10682                      WESTMOUNT           0.008496      Low
# 6509   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
# 6628   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
# 6627   MERCIER-HOCHELAGA-MAISONNEUVE           0.080714     High
#
#           CATEGORIE  Temp_avg  Dew_avg  Hum_avg  Wind_avg  Revenu moyen ($)  \
# 6626         Méfait     -3.82    -7.74    74.75     27.75             36709
# ...

# %%
group1.shape
# Out:
# (10782, 19)

# %%
print(group1.corr())
# Out:
#                         YEAR  FIRE_RISK_RATE_YR  Temp_avg   Dew_avg   Hum_avg  \
# YEAR                1.000000           0.049396 -0.007797 -0.009886  0.003330
# FIRE_RISK_RATE_YR   0.049396           1.000000  0.046496  0.042855 -0.010807
# Temp_avg           -0.007797           0.046496  1.000000  0.936120 -0.221420
# Dew_avg            -0.009886           0.042855  0.936120  1.000000  0.112915
# Hum_avg             0.003330          -0.010807 -0.221420  0.112915  1.000000
# Wind_avg           -0.012861           0.041189 -0.054841 -0.073418 -0.028988
# Revenu moyen ($)    0.012708          -0.183230 -0.012095 -0.008539  0.010464
# Population_Density -0.033791           0.266041  0.018378  0.007328 -0.024359
# NOMBRE_LOGEMENT    -0.018477           0.380003  0.018711  0.008627 -0.015260
# Average_Age         0.024370          -0.316790 -0.037994 -0.023115  0.033052
# Avg_members_family -0.025652          -0.717578 -0.050177 -0.047939  0.010440
#
# ...

# %%
group1.isnull().sum()
# Out:
# DATE                     0
# YEAR                     0
# QUART                    0
# INCIDENT_TYPE_DESC       0
# DESCRIPTION_GROUPE       0
# ARRONDISSEMENT           0
# FIRE_RISK_RATE_YR        0
# RISK_LVL                 0
# CATEGORIE             2334
# Temp_avg                 0
# Dew_avg                  0
# Hum_avg                  0
# Wind_avg                 0
# Revenu moyen ($)         0
# Population_Density       0
# NOMBRE_LOGEMENT          0
# blg_age_level            0
# Average_Age              0
# Avg_members_family       0
# dtype: int64

# %%
group1['DATE'] = group1['DATE'].astype('datetime64[ns]')

# %% [markdown]
# ## create new features: month and day

# %%
group1['MONTH'] = pd.to_datetime(group1['DATE']).dt.month
group1['DAY'] = pd.to_datetime(group1['DATE']).dt.day
group1
# Out:
#             DATE  YEAR QUART INCIDENT_TYPE_DESC DESCRIPTION_GROUPE  \
# 0     2019-01-07  2019  jour    Feu de bâtiment           INCENDIE
# 1     2019-01-11  2019  jour     10-22 avec feu           INCENDIE
# 2     2019-09-27  2019  soir  Feu de cuisinière           INCENDIE
# 3     2019-09-27  2019  soir  Feu de cuisinière           INCENDIE
# 4     2019-01-18  2019  soir     10-22 avec feu           INCENDIE
# ...          ...   ...   ...                ...                ...
# 10777 2019-11-13  2019  nuit    Feu de bâtiment           INCENDIE
# 10778 2019-12-10  2019  jour     10-22 avec feu           INCENDIE
# 10779 2019-07-26  2019  jour    Feu de bâtiment           INCENDIE
# 10780 2019-03-19  2019  jour    Feu de bâtiment           INCENDIE
# 10781 2019-12-24  2019  soir  Feu de cuisinière           INCENDIE
#
#                       ARRONDISSEMENT  FIRE_RISK_RATE_YR RISK_LVL  \
# 0                      POINTE-CLAIRE           0.014108      Low
# ...

# %%
group1 = group1[['YEAR','MONTH','DAY','INCIDENT_TYPE_DESC','DESCRIPTION_GROUPE','ARRONDISSEMENT', 'FIRE_RISK_RATE_YR','RISK_LVL','CATEGORIE','Revenu moyen ($)','Population_Density','NOMBRE_LOGEMENT','blg_age_level','Average_Age','Avg_members_family']]

# %%
group1
# Out:
#        YEAR  MONTH  DAY INCIDENT_TYPE_DESC DESCRIPTION_GROUPE  \
# 0      2019      1    7    Feu de bâtiment           INCENDIE
# 1      2019      1   11     10-22 avec feu           INCENDIE
# 2      2019      9   27  Feu de cuisinière           INCENDIE
# 3      2019      9   27  Feu de cuisinière           INCENDIE
# 4      2019      1   18     10-22 avec feu           INCENDIE
# ...     ...    ...  ...                ...                ...
# 10777  2019     11   13    Feu de bâtiment           INCENDIE
# 10778  2019     12   10     10-22 avec feu           INCENDIE
# 10779  2019      7   26    Feu de bâtiment           INCENDIE
# 10780  2019      3   19    Feu de bâtiment           INCENDIE
# 10781  2019     12   24  Feu de cuisinière           INCENDIE
#
#                       ARRONDISSEMENT  FIRE_RISK_RATE_YR RISK_LVL  \
# 0                      POINTE-CLAIRE           0.014108      Low
# 1                      POINTE-CLAIRE           0.014108      Low
# ...

# %% [markdown]
# ## Encoding related categorical variables with dummy varaibles

# %%
# generate binary values using get_dummies
model1 = pd.get_dummies(group1, columns=['blg_age_level'])

# %%
model1 = model1.drop(columns=['INCIDENT_TYPE_DESC','CATEGORIE','DESCRIPTION_GROUPE','ARRONDISSEMENT','FIRE_RISK_RATE_YR'], inplace=False)

# %%
model1
# Out:
#        YEAR  MONTH  DAY RISK_LVL  Revenu moyen ($)  Population_Density  \
# 0      2019      1    7      Low             51488         1665.605096
# 1      2019      1   11      Low             51488         1665.605096
# 2      2019      9   27      Low             51488         1665.605096
# 3      2019      9   27      Low             51488         1665.605096
# 4      2019      1   18      Low             51488         1665.605096
# ...     ...    ...  ...      ...               ...                 ...
# 10777  2019     11   13      Low             85174         1759.927140
# 10778  2019     12   10      Low             85174         1759.927140
# 10779  2019      7   26      Low             56173          780.211864
# 10780  2019      3   19      Low             56173          780.211864
# 10781  2019     12   24      Low             56173          780.211864
#
#        NOMBRE_LOGEMENT  Average_Age  Avg_members_family  blg_age_level_High  \
# ...

# %% [markdown]
# ### data spliting

# %%
train = model1.loc[model1['YEAR']< 2019]
train.groupby(['YEAR']).count()
test = model1.loc[model1['YEAR']== 2019]
test.groupby(['YEAR']).count()
# Out:
#       MONTH   DAY  RISK_LVL  Revenu moyen ($)  Population_Density  \
# YEAR
# 2015   2205  2205      2205              2205                2205
# 2016   2159  2159      2159              2159                2159
# 2017   2283  2283      2283              2283                2283
# 2018   2027  2027      2027              2027                2027
#
#       NOMBRE_LOGEMENT  Average_Age  Avg_members_family  blg_age_level_High  \
# YEAR
# 2015             2205         2205                2205                2205
# 2016             2159         2159                2159                2159
# 2017             2283         2283                2283                2283
# 2018             2027         2027                2027                2027
#
#       blg_age_level_Low  blg_age_level_Medium
# YEAR
# 2015               2205                  2205
# 2016               2159                  2159
# 2017               2283                  2283
# 2018               2027                  2027
# ...

# %%
y_train = train['RISK_LVL']
X_train= train.drop(columns=['RISK_LVL'], inplace=False)
y_train
# Out:
# 59       Medium
# 60       Medium
# 61       Medium
# 62       Medium
# 63       Medium
#           ...
# 10772       Low
# 10773       Low
# 10774       Low
# 10775       Low
# 10776       Low
# Name: RISK_LVL, Length: 8674, dtype: object

# %%
X_train
# Out:
#        YEAR  MONTH  DAY  Revenu moyen ($)  Population_Density  \
# 59     2016      1   20             28820         7622.986425
# 60     2016      3   10             28820         7622.986425
# 61     2016      3   24             28820         7622.986425
# 62     2016      3   22             28820         7622.986425
# 63     2016      7   21             28820         7622.986425
# ...     ...    ...  ...               ...                 ...
# 10772  2016      3    8             39208         3128.362573
# 10773  2016      6   19             39208         3128.362573
# 10774  2016      1   20             85174         1759.927140
# 10775  2016     11   29             85174         1759.927140
# 10776  2016      8   15             85174         1759.927140
#
#        NOMBRE_LOGEMENT  Average_Age  Avg_members_family  blg_age_level_High  \
# 59            3.028541         41.2                 3.0                   0
# ...

# %%
y_test = test['RISK_LVL']
X_test= test.drop(columns=['RISK_LVL'], inplace=False)
X_test,y_test
# Out:
# (       YEAR  MONTH  DAY  Revenu moyen ($)  Population_Density  \
#  0      2019      1    7             51488         1665.605096
#  1      2019      1   11             51488         1665.605096
#  2      2019      9   27             51488         1665.605096
#  3      2019      9   27             51488         1665.605096
#  4      2019      1   18             51488         1665.605096
#  ...     ...    ...  ...               ...                 ...
#  10777  2019     11   13             85174         1759.927140
#  10778  2019     12   10             85174         1759.927140
#  10779  2019      7   26             56173          780.211864
#  10780  2019      3   19             56173          780.211864
#  10781  2019     12   24             56173          780.211864
#
#         NOMBRE_LOGEMENT  Average_Age  Avg_members_family  blg_age_level_High  \
#  0             1.403955         45.3                 3.0                   0
# ...

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
logreg = log.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.687381404174573
# D:\anacoda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\anacoda\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
show =pd.Series(abs(log.coef_[0]), index=X_train.columns).nlargest(15).plot(kind='barh').invert_yaxis()

# %%
from matplotlib import pyplot
importance = log.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
show = pyplot.bar([x for x in range(len(importance))], importance)
# Out:
# Feature: 0, Score: -0.00366
# Feature: 1, Score: -0.00356
# Feature: 2, Score: -0.00460
# Feature: 3, Score: -0.00000
# Feature: 4, Score: 0.00015
# Feature: 5, Score: 0.04463
# Feature: 6, Score: 0.16619
# Feature: 7, Score: -0.20086
# Feature: 8, Score: -0.08784
# Feature: 9, Score: -0.11006
# Feature: 10, Score: 0.19797

# %% [markdown]
# ## DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
# fit the model
dtree.fit(X_train, y_train)

y_pred = dtree.predict(X_test)

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
# Accuracy: 0.7533206831119544

# %%
# get importance
importance = dtree.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
# Out:
# Feature: 0, Score: 0.19168
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 0.00000
# Feature: 3, Score: 0.00640
# Feature: 4, Score: 0.07261
# Feature: 5, Score: 0.55324
# Feature: 6, Score: 0.12980
# Feature: 7, Score: 0.04628
# Feature: 8, Score: 0.00000
# Feature: 9, Score: 0.00000
# Feature: 10, Score: 0.00000
# Feature: 11, Score: 0.00000
# Feature: 12, Score: 0.00000
# Feature: 13, Score: 0.00000
# <BarContainer object of 14 artists>

# %%
from sklearn import tree
import graphviz 
dot_data = tree.export_graphviz(dtree, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("dtree")
# Out:
# 'dtree.pdf'

# %%
tree.plot_tree(dtree)
# Out:
# [Text(235.37884498906902, 214.42, 'X[10] <= 0.5\ngini = 0.651\nsamples = 8674\nvalue = [3746, 2284, 2644]'),
#  Text(172.4506657930514, 208.38, 'X[8] <= 0.5\ngini = 0.661\nsamples = 6827\nvalue = [2696, 2011, 2120]'),
#  Text(137.1165211388016, 202.34, 'X[9] <= 0.5\ngini = 0.665\nsamples = 4603\nvalue = [1504, 1690, 1409]'),
#  Text(97.74071966302748, 196.3, 'X[12] <= 0.5\ngini = 0.642\nsamples = 3086\nvalue = [769, 1420, 897]'),
#  Text(68.35586826006511, 190.26, 'X[11] <= 0.5\ngini = 0.613\nsamples = 2646\nvalue = [515, 1362, 769]'),
#  Text(46.97878179854303, 184.22, 'X[5] <= 0.5\ngini = 0.51\nsamples = 1847\nvalue = [202, 1196, 449]'),
#  Text(28.21966835548495, 178.18, 'X[7] <= 0.5\ngini = 0.447\nsamples = 1195\nvalue = [100, 848, 247]'),
#  Text(28.08128729608246, 172.14, 'X[3] <= 24.07\ngini = 0.445\nsamples = 1193\nvalue = [98, 848, 247]'),
#  Text(14.49257807959081, 166.1, 'X[3] <= 10.06\ngini = 0.436\nsamples = 1097\nvalue = [91, 790, 216]'),
# ...

# %%
fig = pyplot.figure(figsize=(25,20))
_ = tree.plot_tree(dtree, 
                   filled=True)

# %% [markdown]
# ## random forest

# %%
# random forest for feature importance on a regression problem

from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot

# define the model
randomtree = RandomForestClassifier()
# fit the model
randomtree.fit(X_train, y_train)

y_pred = randomtree.predict(X_test)

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# D:\anacoda\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Accuracy: 0.7533206831119544

# %%
# get importance
importance = randomtree.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.20129
# Feature: 1, Score: 0.01513
# Feature: 2, Score: 0.02438
# Feature: 3, Score: 0.12961
# Feature: 4, Score: 0.16393
# Feature: 5, Score: 0.22594
# Feature: 6, Score: 0.15454
# Feature: 7, Score: 0.04878
# Feature: 8, Score: 0.00178
# Feature: 9, Score: 0.00134
# Feature: 10, Score: 0.00202
# Feature: 11, Score: 0.01253
# Feature: 12, Score: 0.00619
# Feature: 13, Score: 0.01254
# <BarContainer object of 14 artists>

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier

# %%
scaler = MinMaxScaler()
X_train_gbc = scaler.fit_transform(X_train)
X_test_gbc = scaler.transform(X_test)

# %%
X_train_df = pd.DataFrame(X_train)

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8674 entries, 59 to 10776
# Data columns (total 11 columns):
# YEAR                    8674 non-null int64
# MONTH                   8674 non-null int64
# DAY                     8674 non-null int64
# Revenu moyen ($)        8674 non-null int64
# Population_Density      8674 non-null float64
# NOMBRE_LOGEMENT         8674 non-null float64
# Average_Age             8674 non-null float64
# Avg_members_family      8674 non-null float64
# blg_age_level_High      8674 non-null uint8
# blg_age_level_Low       8674 non-null uint8
# blg_age_level_Medium    8674 non-null uint8
# dtypes: float64(4), int64(4), uint8(3)
# memory usage: 635.3 KB

# %%
X_train_gbc
# Out:
# array([[0.33333333, 0.        , 0.63333333, ..., 0.        , 0.        ,
#         1.        ],
#        [0.33333333, 0.18181818, 0.3       , ..., 0.        , 0.        ,
#         1.        ],
#        [0.33333333, 0.18181818, 0.76666667, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.33333333, 0.        , 0.63333333, ..., 0.        , 0.        ,
#         1.        ],
#        [0.33333333, 0.90909091, 0.93333333, ..., 0.        , 0.        ,
#         1.        ],
#        [0.33333333, 0.63636364, 0.46666667, ..., 0.        , 0.        ,
#         1.        ]])

# %%
X_test_gbc
# Out:
# array([[1.33333333, 0.        , 0.2       , ..., 0.        , 0.        ,
#         1.        ],
#        [1.33333333, 0.        , 0.33333333, ..., 0.        , 0.        ,
#         1.        ],
#        [1.33333333, 0.72727273, 0.86666667, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [1.33333333, 0.54545455, 0.83333333, ..., 0.        , 1.        ,
#         0.        ],
#        [1.33333333, 0.18181818, 0.6       , ..., 0.        , 1.        ,
#         0.        ],
#        [1.33333333, 1.        , 0.76666667, ..., 0.        , 1.        ,
#         0.        ]])

# %%
y_train
y_test
# Out:
# 59       Medium
# 60       Medium
# 61       Medium
# 62       Medium
# 63       Medium
#           ...
# 10772       Low
# 10773       Low
# 10774       Low
# 10775       Low
# 10776       Low
# Name: RISK_LVL, Length: 8674, dtype: object
# 0        Low
# 1        Low
# 2        Low
# 3        Low
# 4        Low
#         ...
# 10777    Low
# 10778    Low
# 10779    Low
# 10780    Low
# 10781    Low
# Name: RISK_LVL, Length: 2108, dtype: object

# %%
lr_list = [0.05,0.075,0.08,0.1]

for learning_rate in lr_list:
    gb_clf = GradientBoostingClassifier(n_estimators=12, learning_rate=learning_rate, max_features=2, max_depth=2, random_state=0)
    gb_clf.fit(X_train, y_train)

    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb_clf.score(X_train, y_train)))
    print("Accuracy score (test): {0:.3f}".format(gb_clf.score(X_test, y_test)))
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.05, loss='deviance', max_depth=2,
#                            max_features=2, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=12,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=0, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
# Learning rate:  0.05
# Accuracy score (training): 0.809
# Accuracy score (test): 0.789
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.075, loss='deviance', max_depth=2,
#                            max_features=2, max_leaf_nodes=None,
# ...

# %%
predictions = gb_clf.predict(X_test)

print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))

print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix:
# [[666   0   0]
#  [ 95 517  19]
#  [308   0 503]]
# Classification Report
#               precision    recall  f1-score   support
#
#         High       0.62      1.00      0.77       666
#          Low       1.00      0.82      0.90       631
#       Medium       0.96      0.62      0.75       811
#
#     accuracy                           0.80      2108
#    macro avg       0.86      0.81      0.81      2108
# weighted avg       0.87      0.80      0.80      2108

# %%
# get importance
importance = gb_clf.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
    
show =pd.Series(abs(gb_clf.coef_[0]), index=X_train.columns).nlargest(15).plot(kind='barh')
pyplot.title("Feature Importance")
pyplot.show()
# Out:
# Feature: 0, Score: 0.00770
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 0.00025
# Feature: 3, Score: 0.09024
# Feature: 4, Score: 0.17518
# Feature: 5, Score: 0.30828
# Feature: 6, Score: 0.22800
# Feature: 7, Score: 0.17119
# Feature: 8, Score: 0.00577
# Feature: 9, Score: 0.00520
# Feature: 10, Score: 0.00818
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-26bf9d77b66b> in <module>
#       6     print('Feature: %0d, Score: %.5f' % (i,v))
#       7
# ----> 8 show =pd.Series(abs(gb_clf.coef_[0]), index=X_train.columns).nlargest(15).plot(kind='barh')
#       9 pyplot.title("Feature Importance")
#      10 pyplot.show()
#
# AttributeError: 'GradientBoostingClassifier' object has no attribute 'coef_'

# %%
train, validate, test = np.split(df.sample(frac=1), [int(.6*len(df)), int(.8*len(df))])

# %% [markdown]
# ## SVM support vector machine

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train, y_train)

# %%
y_pred = svclassifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
show =pd.Series(abs(svclassifier.coef_[0]), index=X_train.columns).nlargest(15).plot(kind='barh')
